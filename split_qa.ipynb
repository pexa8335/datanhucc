# %%
import pandas as pd
df = pd.read_csv('D:\Project\EXACT2026\datanhucc\qa2.csv')
df
# Out:
#             id                                           question  \
# 0    QA8000164  A motorboat travels downstream from A to B in ...
# 1    QA8000270  A car travels from A to B at a speed of 56 km/...
# 2    QA8000290  An object AB is placed in front of a diverging...
# 3    QA8000291  An object has a mass of 5 kg. Calculate its po...
# 4    QA8000367  An airplane with a mass of 1 ton is flying at ...
# ..         ...                                                ...
# 264     QA3322  A motorboat is moving at an initial velocity V...
# 265     QA3332  An object undergoes simple harmonic motion wit...
# 266     QA3334  An object undergoes simple harmonic motion wit...
# 267     QA3406  An object undergoes simple harmonic motion wit...
# 268     QA3409  An object undergoes simple harmonic motion. Th...
#
#                                                    cot  \
# 0    Step 1: Identify the requested quantity: the r...
# 1    Step 1: Identify the requested quantity: the d...
# ...
