# %%
import pandas as pd

DATA_PATH = r"D:\Project\EXACT2026\datanhucc\Physics_Problems_Text_Only.csv"

df = pd.read_csv(DATA_PATH)

qa_df = df[df["id"].astype(str).str.match(r"^QA\d+$", na=False)].reset_index(drop=True)

qa_df.to_csv("qa.csv", index=False)


qa_df.head()
# Out:
#           id                                           question  \
# 0  QA8000164  A motorboat travels downstream from A to B in ...
# 1  QA8000270  A car travels from A to B at a speed of 56 km/...
# 2  QA8000290  An object AB is placed in front of a diverging...
# 3  QA8000291  An object has a mass of 5 kg. Calculate its po...
# 4  QA8000367  An airplane with a mass of 1 ton is flying at ...
#
#                                                  cot answer unit
# 0  Step 1: Define the quantities\nLet d be the di...    NaN  NaN
# 1  Step 1: Identify the speed of the car from A t...    NaN  NaN
# 2  Step 1: Identify the parameters and sign conve...    NaN  NaN
# 3  Step 1: Identify the given mass (m) and height...    NaN  NaN
# 4  Step 1: Identify the given values: mass m = 10...    NaN  NaN

# %%
qa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        400 non-null    object
#  1   question  399 non-null    object
#  2   cot       400 non-null    object
#  3   answer    0 non-null      object
#  4   unit      0 non-null      object
# dtypes: object(5)
# memory usage: 15.8+ KB
